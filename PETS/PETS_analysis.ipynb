# %%
import numpy as np
import matplotlib.pyplot as plt
import os

# %% [markdown]
# - Used for envs like Panda reach (sparse and dense) where the goal state depends on the seed and the results had to be saved for each seed

# %%
def save_data(prob, method_name, episodic_rep_returns, mean_episodic_returns, std_episodic_returns):

    # Get the folder where this script is located
    origin_folder = "C:\\Users\\nicle\\Desktop\\QRNN-MPC\\PETS"
    # os.path.dirname(os.path.abspath(__file__))
    # Construct full path to save
    save_path = os.path.join(origin_folder, f"{prob}_{method_name}_results.npz")

    np.savez(
    save_path,
    f"{prob}_{method_name}_results.npz",
    episode_rewards=episodic_rep_returns,
    mean_rewards=mean_episodic_returns,
    std_rewards=std_episodic_returns
    )

# %%
method_name = "PETS"

# %% [markdown]
# ## Cart Pole Continuous

# %%
prob = "CartPoleContinuous"

# %%
CPC_pets_seed0 = np.load("C:\\Users\\nicle\\Desktop\\QRNN-MPC\\PETS\\CartPoleContinuous_PETS_CEM_results_0.npz")
CPC_pets_seed8 = np.load("C:\\Users\\nicle\\Desktop\\QRNN-MPC\\PETS\\CartPoleContinuous_PETS_CEM_results_8.npz")
CPC_pets_seed15 = np.load("C:\\Users\\nicle\\Desktop\\QRNN-MPC\\PETS\\CartPoleContinuous_PETS_CEM_results_15.npz")

# %%
CPC_pets_seed0['episode_rewards'].shape, CPC_pets_seed8['episode_rewards'].shape, CPC_pets_seed15['episode_rewards'].shape
# Out:
# ((1, 300), (1, 300), (1, 300))

# %%
plt.plot(CPC_pets_seed0['mean_rewards'], label='seed0') # , label=f'{method_name}'
plt.plot(CPC_pets_seed8['mean_rewards'], label='seed8')
plt.plot(CPC_pets_seed15['mean_rewards'], label='seed15')
plt.legend()

# %%
episodic_return_seeds = np.array([CPC_pets_seed0['mean_rewards'], CPC_pets_seed8['mean_rewards'], CPC_pets_seed15['mean_rewards']])
mean_episodic_return = np.mean(episodic_return_seeds, axis=0)
std_episodic_return = np.std(episodic_return_seeds, axis=0)
save_data(prob, method_name, episodic_return_seeds, mean_episodic_return, std_episodic_return)

# %%
plt.plot(mean_episodic_return)
plt.fill_between(range(len(mean_episodic_return)), mean_episodic_return - std_episodic_return, mean_episodic_return + std_episodic_return, alpha=0.2)
plt.xlabel('Episode')
plt.ylabel('Mean episodic return')
# Out:
# Text(0, 0.5, 'Mean episodic return')

# %% [markdown]
# ## Pendulum

# %%
prob = "Pendulum"

# %%
# PE_pets = np.load("C:\\Users\\nicle\\anaconda3\\envs\\petscem_sp_py310\\PETS\\Pendulum_PETS_CEM_results.npz") #['mean_reward']
PE_pets_seed0 = np.load("C:\\Users\\nicle\\Desktop\\QRNN-MPC\\PETS\\Pendulum_PETS_CEM_results_0.npz")
PE_pets_seed8 = np.load("C:\\Users\\nicle\\Desktop\\QRNN-MPC\\PETS\\Pendulum_PETS_CEM_results_8.npz")
PE_pets_seed15 = np.load("C:\\Users\\nicle\\Desktop\\QRNN-MPC\\PETS\\Pendulum_PETS_CEM_results_15.npz")

# %%
PE_pets_seed0['episode_rewards'].shape, PE_pets_seed8['episode_rewards'].shape, PE_pets_seed15['episode_rewards'].shape
# Out:
# ((1, 300), (1, 300), (1, 300))

# %%
PE_pets_seed0
# Out:
# NpzFile 'C:\\Users\\nicle\\Desktop\\QRNN-MPC\\PETS\\Pendulum_PETS_CEM_results_0.npz' with keys: episode_rewards, mean_rewards, std_rewards

# %%
plt.plot(PE_pets_seed0['mean_rewards'], label='seed0') # , label=f'{method_name}'
plt.plot(PE_pets_seed8['mean_rewards'], label='seed8')
plt.plot(PE_pets_seed15['mean_rewards'], label='seed15')
plt.legend()

# %%
plt.plot(PE_pets_seed0['mean_rewards'], label='seed0') # , label=f'{method_name}'
plt.plot(PE_pets_seed8['mean_rewards'], label='seed8')
plt.plot(PE_pets_seed15['mean_rewards'], label='seed15')
plt.legend()

# %%
episodic_return_seeds = np.array([PE_pets_seed0['mean_rewards'], PE_pets_seed8['mean_rewards'], PE_pets_seed15['mean_rewards']])
mean_episodic_return = np.mean(episodic_return_seeds, axis=0)
std_episodic_return = np.std(episodic_return_seeds, axis=0)
save_data(prob, method_name, episodic_return_seeds, mean_episodic_return, std_episodic_return)

# %%
plt.plot(mean_episodic_return, label='MPPI')
plt.fill_between(range(len(mean_episodic_return)), mean_episodic_return - std_episodic_return, mean_episodic_return + std_episodic_return, alpha=0.2)
plt.xlabel('Episode')
plt.ylabel('Mean episodic return')
# Out:
# Text(0, 0.5, 'Mean episodic return')

# %% [markdown]
# ## MuJoCo reacher

# %%
prob = "MuJoCoReacher"

# %%
# RE_pets = np.load("C:\\Users\\nicle\\anaconda3\\envs\\petscem_sp_py310\\PETS\\MuJoCoReacher_PETS_CEM_results.npz")#['mean_reward']
MRE_pets_0 = np.load("C:\\Users\\nicle\\Desktop\\QRNN-MPC\\PETS\\Reacher_PETS_CEM_results_0.npz")['mean_rewards'] #['mean_reward']
MRE_pets_8 = np.load("C:\\Users\\nicle\\Desktop\\QRNN-MPC\\PETS\\Reacher_PETS_CEM_results_8.npz")['mean_rewards']
MRE_pets_15 = np.load("C:\\Users\\nicle\\Desktop\\QRNN-MPC\\PETS\\Reacher_PETS_CEM_results_15.npz")['mean_rewards']

# %%
MRE_pets_0.shape, MRE_pets_8.shape, MRE_pets_15.shape
# Out:
# ((300,), (300,), (300,))

# %%
plt.plot(MRE_pets_0, label=f'{method_name}')
plt.plot(MRE_pets_8, label=f'{method_name}')
plt.plot(MRE_pets_15, label=f'{method_name}')

# %%
episodic_return_seeds = np.array([MRE_pets_0, MRE_pets_8, MRE_pets_15])
mean_episodic_return = np.mean(episodic_return_seeds, axis=0)
std_episodic_return = np.std(episodic_return_seeds, axis=0)
save_data(prob, method_name, episodic_return_seeds, mean_episodic_return, std_episodic_return)

# %%
plt.plot(mean_episodic_return, label=f'{method_name}')
plt.fill_between(range(len(mean_episodic_return)), mean_episodic_return - std_episodic_return, mean_episodic_return + std_episodic_return, alpha=0.2)
plt.xlabel('Episode')
plt.ylabel('Mean episodic return')

# %% [markdown]
# ## Mountain car continuous

# %%
prob = "MountainCarContinuous"

# %%
# MCC_mppi = np.load("C:\\Users\\nicle\\anaconda3\\envs\\petscem_sp_py310\\PETS\\MountainCarContinuous_PETS_CEM_results.npz")#['mean_reward']
MCC_pets_seed0 = np.load("C:\\Users\\nicle\\anaconda3\\envs\\petscem_sp_py310\\PETS\\MountainCarContinuous_PETS_CEM_results_seed0.npz")['arr_0']#['mean_reward']
MCC_pets_seed8 = np.load("C:\\Users\\nicle\\anaconda3\\envs\\petscem_sp_py310\\PETS\\MountainCarContinuous_PETS_CEM_results_seed8.npz")['arr_0']#['mean_reward']
# MCC_pets_seed15 = np.load("C:\\Users\\nicle\\anaconda3\\envs\\petscem_sp_py310\\PETS\\MountainCarContinuous_PETS_CEM_results_seed15.npz")['arr_0']#['mean_reward']
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 2
#       1 # MCC_mppi = np.load("C:\\Users\\nicle\\anaconda3\\envs\\petscem_sp_py310\\PETS\\MountainCarContinuous_PETS_CEM_results.npz")#['mean_reward']
# ----> 2 MCC_pets_seed0 = np.load("C:\\Users\\nicle\\anaconda3\\envs\\petscem_sp_py310\\PETS\\MountainCarContinuous_PETS_CEM_results_seed0.npz")['arr_0']#['mean_reward']
#       3 MCC_pets_seed8 = np.load("C:\\Users\\nicle\\anaconda3\\envs\\petscem_sp_py310\\PETS\\MountainCarContinuous_PETS_CEM_results_seed8.npz")['arr_0']#['mean_reward']
#       4 # MCC_pets_seed15 = np.load("C:\\Users\\nicle\\anaconda3\\envs\\petscem_sp_py310\\PETS\\MountainCarContinuous_PETS_CEM_results_seed15.npz")['arr_0']#['mean_reward']
#
# ...

# %%
# MCC_mppi['episode_rewards'].shape
MCC_pets_seed0.shape, MCC_pets_seed8.shape#, MCC_pets_seed15.shape
# Out:
# ((300,), (300,))

# %%
# plt.plot(MCC_mppi['mean_rewards'], label='MPPI')
plt.plot(MCC_pets_seed0, label=f'{method_name} seed 0')
plt.plot(MCC_pets_seed8, label=f'{method_name} seed 8')
plt.plot(MCC_pets_seed15, label=f'{method_name} seed 15')
plt.xlabel('Episode')
plt.ylabel('Mean episodic return')
# Out:
# Text(0, 0.5, 'Mean episodic return')

# %%
episodic_return_seeds = np.array([MCC_pets_seed0, MCC_pets_seed8, MCC_pets_seed15])
mean_episodic_return = np.mean(episodic_return_seeds, axis=0)
std_episodic_return = np.std(episodic_return_seeds, axis=0)
save_data(prob, method_name, episodic_return_seeds, mean_episodic_return, std_episodic_return)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 episodic_return_seeds = np.array([MCC_mppi_seed0, MCC_mppi_seed8, MCC_mppi_seed15])
#       2 mean_episodic_return = np.mean(episodic_return_seeds, axis=0)
#       3 std_episodic_return = np.std(episodic_return_seeds, axis=0)
#
# NameError: name 'MCC_mppi_seed15' is not defined

# %%
plt.plot(mean_episodic_return, label='MPPI')
plt.fill_between(range(len(mean_episodic_return)), mean_episodic_return - std_episodic_return, mean_episodic_return + std_episodic_return, alpha=0.2)
plt.xlabel('Episode')
plt.ylabel('Mean episodic return')

# %% [markdown]
# ## Lunar lander continuous

# %%
prob = "LunarLanderContinuous"
method_name = "MPPI"

# %%
plt.plot(np.load("C:\\Users\\nicle\\Desktop\\QRNN-MPC\\PETS\\LunarLanderContinuous_PETS_CEM_results_0.npz")['mean_rewards'])

# %%
# # MCC_mppi = np.load("C:\\Users\\nicle\\Desktop\\QRNN-MPC\\mppi\\MountainCarContinuous_MPPI_results.npz")#['mean_reward']

LLC_pets_seed0 = np.load("C:\\Users\\nicle\\Desktop\\QRNN-MPC\\PETS\\LunarLanderContinuous_PETS_CEM_results_0.npz")['mean_rewards']
LLC_pets_seed8 = np.load("C:\\Users\\nicle\\Desktop\\QRNN-MPC\\PETS\\LunarLanderContinuous_PETS_CEM_results_8.npz")['mean_rewards']#['mean_reward']
LLC_pets_seed15 = np.load("C:\\Users\\nicle\\Desktop\\QRNN-MPC\\PETS\\LunarLanderContinuous_PETS_CEM_results_15.npz")['mean_rewards']#['mean_reward']

# %%
# LLC_mppi_seed0['episode_rewards'].shape
LLC_pets_seed0.shape, LLC_pets_seed8.shape, LLC_pets_seed15.shape
# Out:
# ((300,), (300,), (300,))

# %%
# plt.plot(LLC_mppi['mean_rewards'], label='MPPI')
plt.plot(LLC_pets_seed0, label=f'{method_name} seed 0')
plt.plot(LLC_pets_seed8, label=f'{method_name} seed 8')
plt.plot(LLC_pets_seed15, label=f'{method_name} seed 15')
plt.xlabel('Episode')
plt.ylabel('Mean episodic return')
# Out:
# Text(0, 0.5, 'Mean episodic return')

# %%
episodic_return_seeds = np.array([LLC_pets_seed0, LLC_pets_seed8, LLC_pets_seed15])
mean_episodic_return = np.mean(episodic_return_seeds, axis=0)
std_episodic_return = np.std(episodic_return_seeds, axis=0)
save_data(prob, method_name, episodic_return_seeds, mean_episodic_return, std_episodic_return)

# %%
plt.plot(mean_episodic_return, label=f'{method_name}')
plt.fill_between(range(len(mean_episodic_return)), mean_episodic_return - std_episodic_return, mean_episodic_return + std_episodic_return, alpha=0.2)
plt.xlabel('Episode')
plt.ylabel('Mean episodic return')
# Out:
# Text(0, 0.5, 'Mean episodic return')

# %% [markdown]
# ## Panda reach

# %%
prob = "PandaReach"

# %%
PR_pets_0 = np.load("C:\\Users\\nicle\\Desktop\\QRNN-MPC\\PETS\\PandaReacher_PETS_CEM_results_0.npz")['mean_rewards'] #['mean_reward']
PR_pets_8 = np.load("C:\\Users\\nicle\\Desktop\\QRNN-MPC\\PETS\\PandaReacher_PETS_CEM_results_8.npz")['mean_rewards']
PR_pets_15 = np.load("C:\\Users\\nicle\\Desktop\\QRNN-MPC\\PETS\\PandaReacher_PETS_CEM_results_15.npz")['mean_rewards']

# %%
episodic_return_seeds = np.array([PR_pets_0, PR_pets_8, PR_pets_15])
mean_episodic_return = np.mean(episodic_return_seeds, axis=0)
std_episodic_return = np.std(episodic_return_seeds, axis=0)
save_data(prob, method_name, episodic_return_seeds, mean_episodic_return, std_episodic_return)

# %%
plt.plot(mean_episodic_return, label=f'{method_name}')
plt.fill_between(range(len(mean_episodic_return)), mean_episodic_return - std_episodic_return, mean_episodic_return + std_episodic_return, alpha=0.2)
plt.xlabel('Episode')
plt.ylabel('Mean episodic return')
# Out:
# Text(0, 0.5, 'Mean episodic return')

# %% [markdown]
# ### Test

# %%
import gymnasium as gym
import panda_gym

class DictToBoxWrapper(gym.ObservationWrapper):
    def __init__(self, env):
        super().__init__(env)
        if isinstance(env.observation_space, gym.spaces.Dict):
            self.observation_space = env.observation_space['observation']
        else:
            self.observation_space = env.observation_space
    
    def observation(self, obs):
        return obs['observation'] if isinstance(obs, dict) else obs
    
class ResetStepWrapper(gym.Wrapper):
    def reset(self, **kwargs):
        # print("self.env.reset(**kwargs) ", self.env.reset(**kwargs), "\n")
        # obs, info = self.env.reset(**kwargs) # Discard info
        
        # result = self.env.reset(**kwargs) # Discard info
        # obs, info = self.env.reset(**kwargs) # Discard info
        
        # if isinstance(result, tuple) and len(result) == 2:
        #     obs = result[0]  # drop the infos
        # else:
        #     obs = result  # keep as is
        # print("result ", result, "\n")
        
        print("self.env.reset(**kwargs)[0] ", self.env.reset(**kwargs)[0], "\n")
        return self.env.reset(**kwargs)[0] # obs
    
    def step(self, action):
        result = self.env.step(action)
        
        if len(result) == 5:
            obs, reward, terminated, truncated, info = result
            done = terminated or truncated
        else:
            obs, reward, done, info = result
        
        # obs, reward, terminated, truncated, info = self.env.step(action)
        
        return obs, reward, done, info
    

env = gym.make("PandaReach-v3")

env.reset(seed=15)

env.reset(seed=15)[0], env.reset(seed=15)[1]
env = DictToBoxWrapper(env)  # Converts Dict → Box
env = ResetStepWrapper(env)


env.reset(seed=15)
obs_shape = env.observation_space.shape
act_shape = env.action_space.shape
print("obs_shape", obs_shape, "\n")
print("act_shape", act_shape, "\n")
print("Action Space:", env.action_space)
print("Observation Space:", env.observation_space)

env.reset()

env.step(env.action_space.sample())  # Take a random action

# %% [markdown]
# ## Panda reach dense

# %%
prob = "PandaReachDense"
method = "MPPI"

# %%
PRD_pets_0 = np.load("C:\\Users\\nicle\\Desktop\\QRNN-MPC\\PETS\\PandaReacherDense_PETS_CEM_results_0.npz")['mean_rewards'] #['mean_reward']
PRD_pets_8 = np.load("C:\\Users\\nicle\\Desktop\\QRNN-MPC\\PETS\\PandaReacherDense_PETS_CEM_results_8.npz")['mean_rewards']
PRD_pets_15 = np.load("C:\\Users\\nicle\\Desktop\\QRNN-MPC\\PETS\\PandaReacherDense_PETS_CEM_results_15.npz")['mean_rewards']

# %%
episodic_return_seeds = np.array([PRD_pets_0, PRD_pets_8, PRD_pets_15])
mean_episodic_return = np.mean(episodic_return_seeds, axis=0)
std_episodic_return = np.std(episodic_return_seeds, axis=0)
save_data(prob, method_name, episodic_return_seeds, mean_episodic_return, std_episodic_return)

# %%
plt.plot(mean_episodic_return, label=f'{method_name}')
plt.fill_between(range(len(mean_episodic_return)), mean_episodic_return - std_episodic_return, mean_episodic_return + std_episodic_return, alpha=0.2)
plt.xlabel('Episode')
plt.ylabel('Mean episodic return')
# Out:
# Text(0, 0.5, 'Mean episodic return')

# %% [markdown]
# ## Inverted pendulum

# %%
# IP_mppi_0 = np.load("C:\\Users\\nicle\\anaconda3\\envs\\petscem_sp_py310\\PETS\\InvertedPendulum_PETS_CEM_results_seed0.npz")['arr_0'] #['mean_reward']
# IP_mppi_8 = np.load("C:\\Users\\nicle\\anaconda3\\envs\\petscem_sp_py310\\PETS\\InvertedPendulum_PETS_CEM_results_seed8.npz")['arr_0']
# IP_mppi_15 = np.load("C:\\Users\\nicle\\anaconda3\\envs\\petscem_sp_py310\\PETS\\InvertedPendulum_PETS_CEM_results_seed15.npz.npz")['arr_0']

IP_mppi = np.load("C:\\Users\\nicle\\Desktop\\QRNN-MPC\\PETS\\InvertedPendulum_PETS_CEM_results.npz")

# %%
IP_mppi['episode_rewards'].shape

# IP_mppi_8.shape, IP_mppi_15.shape
# Out:
# (3, 300)

# %%
plt.plot(IP_mppi['mean_rewards'], label=f'{method_name}')
# plt.plot(IP_mppi_8, label='MPPI seed 8')
# plt.plot(IP_mppi_15, label='MPPI seed 15')
