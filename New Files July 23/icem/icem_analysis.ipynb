# %%
import numpy as np
import matplotlib.pyplot as plt
import os

# %% [markdown]
# - Used for envs like Panda reach (sparse and dense) where the goal state depends on the seed and the _results had to be saved for each seed

# %%
def save_data(prob, method_name, episodic_rep_returns, mean_episodic_returns, std_episodic_returns):

    # Get the folder where this script is located
    origin_folder = "C:\\Users\\nicle\\Desktop\\QRNN-MPC\\icem"
    # os.path.dirname(os.path.abspath(__file__))
    # Construct full path to save
    save_path = os.path.join(origin_folder, f"{prob}_{method_name}_results_June25.npz")

    np.savez(
    save_path,
    # f"{prob}_{method_name}__results.npz",
    episode_rewards=episodic_rep_returns,
    mean_rewards=mean_episodic_returns,
    std_rewards=std_episodic_returns
    )

# %%
method_name = "iCEM"

# %% [markdown]
# ## Pendulum

# %%
PE_cem = np.load("C:\\Users\\nicle\\Desktop\\QRNN-MPC\\icem\\Pendulum_iCEM_results_June25.npz")#['mean_reward']

# %%
PE_cem['episode_rewards'].shape
# Out:
# (3, 300)

# %%
plt.plot(PE_cem['mean_rewards'], label='icem')

# %% [markdown]
# ## MuJoCo reacher

# %%
RE_cem = np.load("C:\\Users\\nicle\\Desktop\\QRNN-MPC\\icem\\MuJoCoReacher_iCEM_results_June25.npz")#['mean_reward']\

# %%
RE_cem['episode_rewards'].shape
# Out:
# (3, 400)

# %%
plt.plot(RE_cem['mean_rewards'], label='icem')
plt.xlabel('Episode')
plt.ylabel('Mean episodic return')
# Out:
# Text(0, 0.5, 'Mean episodic return')

# %% [markdown]
# ## Mountain car continuous

# %%
prob = "MountainCarContinuous"

# %%
# MCC_mppi = np.load("C:\\Users\\nicle\\Desktop\\QRNN-MPC\\mppi\\MountainCarContinuous_MPPI__results.npz")#['mean_reward']
MCC_iCEM_seed0 = np.load("C:\\Users\\nicle\\Desktop\\QRNN-MPC\\icem\\MountainCarContinuous_iCEM_results_seed0_June27.npz")['arr_0']#['mean_reward']
MCC_iCEM_seed8 = np.load("C:\\Users\\nicle\\Desktop\\QRNN-MPC\\icem\\MountainCarContinuous_iCEM_results_seed8_June27.npz")['arr_0']#['mean_reward']
MCC_iCEM_seed15 = np.load("C:\\Users\\nicle\\Desktop\\QRNN-MPC\\icem\\MountainCarContinuous_iCEM_results_seed15_June27.npz")['arr_0']#['mean_reward']

# %%
# MCC_mppi['episode_rewards'].shape
MCC_iCEM_seed0.shape, MCC_iCEM_seed8.shape, MCC_iCEM_seed15.shape
# Out:
# ((300,), (300,), (300,))

# %%
# plt.plot(MCC_mppi['mean_rewards'], label='MPPI')
plt.plot(MCC_iCEM_seed0, label='icem seed 0')
plt.plot(MCC_iCEM_seed8, label='icem seed 8')
plt.plot(MCC_iCEM_seed15, label='icem seed 15')
plt.xlabel('Episode')
plt.ylabel('Mean episodic return')
# Out:
# Text(0, 0.5, 'Mean episodic return')

# %%
episodic_return_seeds = np.array([MCC_iCEM_seed0, MCC_iCEM_seed8, MCC_iCEM_seed15])
mean_episodic_return = np.mean(episodic_return_seeds, axis=0)
std_episodic_return = np.std(episodic_return_seeds, axis=0)
save_data(prob, method_name, episodic_return_seeds, mean_episodic_return, std_episodic_return)

# %%
plt.plot(mean_episodic_return, label='MPPI')
plt.fill_between(range(len(mean_episodic_return)), mean_episodic_return - std_episodic_return, mean_episodic_return + std_episodic_return, alpha=0.2)
plt.xlabel('Episode')
plt.ylabel('Mean episodic return')
# Out:
# Text(0, 0.5, 'Mean episodic return')

# %% [markdown]
# ## Lunar lander continuous

# %%
prob = "LunarLanderContinuous"

# %%
# # MCC_mppi = np.load("C:\\Users\\nicle\\Desktop\\QRNN-MPC\\mppi\\MountainCarContinuous_MPPI__results.npz")#['mean_reward']
LLC_iCEMseed0 = np.load("C:\\Users\\nicle\\Desktop\\QRNN-MPC\\icem\\LunarLanderContinuous_iCEM_results_seed0.npz")['arr_0']#['mean_reward']
LLC_iCEMseed8 = np.load("C:\\Users\\nicle\\Desktop\\QRNN-MPC\\icem\\LunarLanderContinuous_iCEM_results_seed8.npz")['arr_0']#['mean_reward']
LLC_iCEMseed15 = np.load("C:\\Users\\nicle\\Desktop\\QRNN-MPC\\icem\\LunarLanderContinuous_iCEM_results_seed15.npz")['arr_0']#['mean_reward']

# %%
# LLC_mppi_seed0['episode_rewards'].shape
LLC_iCEMseed0.shape, LLC_iCEMseed8.shape, LLC_iCEMseed15.shape
# Out:
# ((300,), (300,), (300,))

# %%
# plt.plot(LLC_mppi['mean_rewards'], label='MPPI')
plt.plot(LLC_iCEMseed0, label='MPPI seed 0')
plt.plot(LLC_iCEMseed8, label='MPPI seed 8')
plt.plot(LLC_iCEMseed15, label='MPPI seed 15')
plt.xlabel('Episode')
plt.ylabel('Mean episodic return')
# Out:
# Text(0, 0.5, 'Mean episodic return')

# %%
episodic_return_seeds = np.array([LLC_iCEMseed0, LLC_iCEMseed8, LLC_iCEMseed15])
mean_episodic_return = np.mean(episodic_return_seeds, axis=0)
std_episodic_return = np.std(episodic_return_seeds, axis=0)
save_data(prob, method_name, episodic_return_seeds, mean_episodic_return, std_episodic_return)

# %%
plt.plot(mean_episodic_return, label='icem')
plt.fill_between(range(len(mean_episodic_return)), mean_episodic_return - std_episodic_return, mean_episodic_return + std_episodic_return, alpha=0.2)
plt.xlabel('Episode')
plt.ylabel('Mean episodic return')
# Out:
# Text(0, 0.5, 'Mean episodic return')

# %% [markdown]
# ## Panda reach

# %%
prob = "PandaReach"

# %%
PR_iCEM0 = np.load("C:\\Users\\nicle\\Desktop\\QRNN-MPC\\icem\\PandaReach_iCEM_results_seed0_June27.npz")['arr_0'] #['mean_reward']
PR_iCEM8 = np.load("C:\\Users\\nicle\\Desktop\\QRNN-MPC\\icem\\PandaReach_iCEM_results_seed8_June27.npz")['arr_0']
PR_iCEM15 = np.load("C:\\Users\\nicle\\Desktop\\QRNN-MPC\\icem\\PandaReach_iCEM_results_seed15_June27.npz")['arr_0']

# %%
plt.plot(PR_iCEM0, label='icem seed 0')
plt.plot(PR_iCEM8, label='icem seed 8')
plt.plot(PR_iCEM15, label='icem seed 15')

# %%
episodic_return_seeds = np.array([PR_iCEM0, PR_iCEM8, PR_iCEM15])
mean_episodic_return = np.mean(episodic_return_seeds, axis=0)
std_episodic_return = np.std(episodic_return_seeds, axis=0)
save_data(prob, method_name, episodic_return_seeds, mean_episodic_return, std_episodic_return)

# %%
plt.plot(mean_episodic_return, label='CEM')
plt.fill_between(range(len(mean_episodic_return)), mean_episodic_return - std_episodic_return, mean_episodic_return + std_episodic_return, alpha=0.2)
plt.xlabel('Episode')
plt.ylabel('Mean episodic return')
# Out:
# Text(0, 0.5, 'Mean episodic return')

# %% [markdown]
# ## Panda reach dense

# %%
prob = "PandaReachDense"

# %%
PRD_iCEM0 = np.load("C:\\Users\\nicle\\Desktop\\QRNN-MPC\\icem\\PandaReachDense_iCEM_results_seed0_June27.npz")['arr_0'] #['mean_reward']
PRD_iCEM8 = np.load("C:\\Users\\nicle\\Desktop\\QRNN-MPC\\icem\\PandaReachDense_iCEM_results_seed8_June27.npz")['arr_0']
PRD_iCEM15 = np.load("C:\\Users\\nicle\\Desktop\\QRNN-MPC\\icem\\PandaReachDense_iCEM_results_seed15_June27.npz")['arr_0']

# %%
episodic_return_seeds = np.array([PRD_iCEM0, PRD_iCEM8, PRD_iCEM15])
mean_episodic_return = np.mean(episodic_return_seeds, axis=0)
std_episodic_return = np.std(episodic_return_seeds, axis=0)
save_data(prob, method_name, episodic_return_seeds, mean_episodic_return, std_episodic_return)

# %%
plt.plot(mean_episodic_return, label='icem')
plt.fill_between(range(len(mean_episodic_return)), mean_episodic_return - std_episodic_return, mean_episodic_return + std_episodic_return, alpha=0.2)
plt.xlabel('Episode')
plt.ylabel('Mean episodic return')
# Out:
# Text(0, 0.5, 'Mean episodic return')

# %% [markdown]
# ## Inverted pendulum

# %% [markdown]
# <!-- ## Inverted pendulum -->

# %%
prob = "InvertedPendulum"

# %%
IP_iCEM_0 = np.load("C:\\Users\\nicle\\Desktop\\QRNN-MPC\\icem\\InvertedPendulum_iCEM_results_seed0_June25.npz")['arr_0'][:300] #['mean_reward']
IP_iCEM_8 = np.load("C:\\Users\\nicle\\Desktop\\QRNN-MPC\\icem\\InvertedPendulum_iCEM_results_seed8_June25.npz")['arr_0']
IP_iCEM_15 = np.load("C:\\Users\\nicle\\Desktop\\QRNN-MPC\\icem\\InvertedPendulum_iCEM_results_seed15_June25.npz")['arr_0']

# IP_mppi = np.load("C:\\Users\\nicle\\Desktop\\QRNN-MPC\\mppi\\InvertedPendulum_MPPI__results.npz")

# %%
# IP_mppi['episode_rewards'].shape

IP_iCEM_0.shape, IP_iCEM_8.shape, IP_iCEM_15.shape
# Out:
# ((300,), (300,), (300,))

# %%
# plt.plot(IP_mppi['mean_rewards'], label='MPPI')
plt.plot(IP_iCEM_0, label='MPPI seed 0')
plt.plot(IP_iCEM_8, label='MPPI seed 8')
plt.plot(IP_iCEM_15, label='MPPI seed 15')

# %%
episodic_return_seeds = np.array([IP_iCEM_0, IP_iCEM_8, IP_iCEM_15])
mean_episodic_return = np.mean(episodic_return_seeds, axis=0)
std_episodic_return = np.std(episodic_return_seeds, axis=0)
save_data(prob, method_name, episodic_return_seeds, mean_episodic_return, std_episodic_return)

# %%
plt.plot(mean_episodic_return, label='MPPI')
plt.fill_between(range(len(mean_episodic_return)), mean_episodic_return - std_episodic_return, mean_episodic_return + std_episodic_return, alpha=0.2)
plt.xlabel('Episode')
plt.ylabel('Mean episodic return')
# Out:
# Text(0, 0.5, 'Mean episodic return')

# %% [markdown]
# ## Cart pole continuous

# %%
prob = "CPC"

# %%
CPC_iCEM0 = np.load("C:\\Users\\nicle\\Desktop\\QRNN-MPC\\icem\\CPC_iCEM_results_seed0_June25.npz")['arr_0'][:300] #['mean_reward']
CPC_iCEM8 = np.load("C:\\Users\\nicle\\Desktop\\QRNN-MPC\\icem\\CPC_iCEM_results_seed8_June25.npz")['arr_0']
CPC_iCEM15 = np.load("C:\\Users\\nicle\\Desktop\\QRNN-MPC\\icem\\CPC_iCEM_results_seed15_June25.npz")['arr_0']

# IP_mppi = np.load("C:\\Users\\nicle\\Desktop\\QRNN-MPC\\mppi\\InvertedPendulum_MPPI__results.npz")

# %%
CPC_iCEM0.shape, CPC_iCEM8.shape, CPC_iCEM15.shape
# Out:
# ((300,), (300,), (300,))

# %%
# plt.plot(IP_mppi['mean_rewards'], label='MPPI')
plt.plot(CPC_iCEM0, label='icem seed 0')
plt.plot(CPC_iCEM8, label='icem seed 8')
plt.plot(CPC_iCEM15, label='icem seed 15')

# %%
episodic_return_seeds = np.array([CPC_iCEM0, CPC_iCEM8, CPC_iCEM15])
mean_episodic_return = np.mean(episodic_return_seeds, axis=0)
std_episodic_return = np.std(episodic_return_seeds, axis=0)
save_data(prob, method_name, episodic_return_seeds, mean_episodic_return, std_episodic_return)

# %%
plt.plot(mean_episodic_return, label='icem')
plt.fill_between(range(len(mean_episodic_return)), mean_episodic_return - std_episodic_return, mean_episodic_return + std_episodic_return, alpha=0.2)
plt.xlabel('Episode')
plt.ylabel('Mean episodic return')
# Out:
# Text(0, 0.5, 'Mean episodic return')
