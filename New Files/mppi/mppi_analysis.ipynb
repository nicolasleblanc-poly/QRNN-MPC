# %%
import numpy as np
import matplotlib.pyplot as plt
import os

# %% [markdown]
# - Used for envs like Panda reach (sparse and dense) where the goal state depends on the seed and the results had to be saved for each seed

# %%
def save_data(prob, method_name, episodic_rep_returns, mean_episodic_returns, std_episodic_returns):

    # Get the folder where this script is located
    origin_folder = "C:\\Users\\nicle\\Desktop\\QRNN-MPC\\mppi"
    # os.path.dirname(os.path.abspath(__file__))
    # Construct full path to save
    save_path = os.path.join(origin_folder, f"{prob}_{method_name}_results_June25.npz")

    np.savez(
    save_path,
    # f"{prob}_{method_name}_results.npz",
    episode_rewards=episodic_rep_returns,
    mean_rewards=mean_episodic_returns,
    std_rewards=std_episodic_returns
    )

# %%
method_name = "MPPI"

# %% [markdown]
# ## Pendulum

# %%
PE_mppi = np.load("C:\\Users\\nicle\\Desktop\\QRNN-MPC\\mppi\\Pendulum_MPPI_results_June25.npz")#['mean_reward']

# %%
PE_mppi['episode_rewards'].shape
# Out:
# (3, 300)

# %%
plt.plot(PE_mppi['mean_rewards'], label='MPPI')

# %% [markdown]
# ## MuJoCo reacher

# %%
RE_mppi = np.load("C:\\Users\\nicle\\Desktop\\QRNN-MPC\\mppi\\MuJoCoReacher_MPPI_results_June25.npz")#['mean_reward']\

# %%
RE_mppi['episode_rewards'].shape
# Out:
# (3, 400)

# %%
plt.plot(RE_mppi['mean_rewards'], label='MPPI')
plt.xlabel('Episode')
plt.ylabel('Mean episodic return')
# Out:
# Text(0, 0.5, 'Mean episodic return')

# %% [markdown]
# ## Mountain car continuous

# %%
prob = "MountainCarContinuous"

# %%
# MCC_mppi = np.load("C:\\Users\\nicle\\Desktop\\QRNN-MPC\\mppi\\MountainCarContinuous_MPPI_results.npz")#['mean_reward']
MCC_mppi_seed0 = np.load("C:\\Users\\nicle\\Desktop\\QRNN-MPC\\mppi\\MountainCarContinuous_MPPI_results_seed0_June25.npz")['arr_0']#['mean_reward']
MCC_mppi_seed8 = np.load("C:\\Users\\nicle\\Desktop\\QRNN-MPC\\mppi\\MountainCarContinuous_MPPI_results_seed8_June25.npz")['arr_0']#['mean_reward']
MCC_mppi_seed15 = np.load("C:\\Users\\nicle\\Desktop\\QRNN-MPC\\mppi\\MountainCarContinuous_MPPI_results_seed15_June25.npz")['arr_0']#['mean_reward']

# %%
# MCC_mppi['episode_rewards'].shape
MCC_mppi_seed0.shape, MCC_mppi_seed8.shape, MCC_mppi_seed15.shape
# Out:
# ((300,), (300,), (300,))

# %%
# plt.plot(MCC_mppi['mean_rewards'], label='MPPI')
plt.plot(MCC_mppi_seed0, label='MPPI seed 0')
plt.plot(MCC_mppi_seed8, label='MPPI seed 8')
plt.plot(MCC_mppi_seed15, label='MPPI seed 15')
plt.xlabel('Episode')
plt.ylabel('Mean episodic return')
# Out:
# Text(0, 0.5, 'Mean episodic return')

# %%
episodic_return_seeds = np.array([MCC_mppi_seed0, MCC_mppi_seed8, MCC_mppi_seed15])
mean_episodic_return = np.mean(episodic_return_seeds, axis=0)
std_episodic_return = np.std(episodic_return_seeds, axis=0)
save_data(prob, method_name, episodic_return_seeds, mean_episodic_return, std_episodic_return)

# %%
plt.plot(mean_episodic_return, label='MPPI')
plt.fill_between(range(len(mean_episodic_return)), mean_episodic_return - std_episodic_return, mean_episodic_return + std_episodic_return, alpha=0.2)
plt.xlabel('Episode')
plt.ylabel('Mean episodic return')
# Out:
# Text(0, 0.5, 'Mean episodic return')

# %% [markdown]
# ## Lunar lander continuous

# %%
prob = "LunarLanderContinuous"

# %%
# # MCC_mppi = np.load("C:\\Users\\nicle\\Desktop\\QRNN-MPC\\mppi\\MountainCarContinuous_MPPI_results.npz")#['mean_reward']
LLC_mppi_seed0 = np.load("C:\\Users\\nicle\\Desktop\\QRNN-MPC\\mppi\\LunarLanderContinuous_MPPI_results_seed0_June25.npz")['arr_0']#['mean_reward']
LLC_mppi_seed8 = np.load("C:\\Users\\nicle\\Desktop\\QRNN-MPC\\mppi\\LunarLanderContinuous_MPPI_results_seed8_June25.npz")['arr_0']#['mean_reward']
LLC_mppi_seed15 = np.load("C:\\Users\\nicle\\Desktop\\QRNN-MPC\\mppi\\LunarLanderContinuous_MPPI_results_seed15_June25.npz")['arr_0']#['mean_reward']

# %%
# LLC_mppi_seed0['episode_rewards'].shape
LLC_mppi_seed0.shape, LLC_mppi_seed8.shape, LLC_mppi_seed15.shape
# Out:
# ((300,), (300,), (300,))

# %%
# plt.plot(LLC_mppi['mean_rewards'], label='MPPI')
plt.plot(LLC_mppi_seed0, label='MPPI seed 0')
plt.plot(LLC_mppi_seed8, label='MPPI seed 8')
plt.plot(LLC_mppi_seed15, label='MPPI seed 15')
plt.xlabel('Episode')
plt.ylabel('Mean episodic return')
# Out:
# Text(0, 0.5, 'Mean episodic return')

# %%
episodic_return_seeds = np.array([LLC_mppi_seed0, LLC_mppi_seed8, LLC_mppi_seed15])
mean_episodic_return = np.mean(episodic_return_seeds, axis=0)
std_episodic_return = np.std(episodic_return_seeds, axis=0)
save_data(prob, method_name, episodic_return_seeds, mean_episodic_return, std_episodic_return)

# %%
plt.plot(mean_episodic_return, label='MPPI')
plt.fill_between(range(len(mean_episodic_return)), mean_episodic_return - std_episodic_return, mean_episodic_return + std_episodic_return, alpha=0.2)
plt.xlabel('Episode')
plt.ylabel('Mean episodic return')
# Out:
# Text(0, 0.5, 'Mean episodic return')

# %% [markdown]
# ## Panda reach

# %%
prob = "PandaReach"

# %%
PR_mppi_0 = np.load("C:\\Users\\nicle\\Desktop\\QRNN-MPC\\mppi\\PandaReach_MPPI_results_seed0_June27.npz")['arr_0'] #['mean_reward']
PR_mppi_8 = np.load("C:\\Users\\nicle\\Desktop\\QRNN-MPC\\mppi\\PandaReach_MPPI_results_seed8_June27.npz")['arr_0']
PR_mppi_15 = np.load("C:\\Users\\nicle\\Desktop\\QRNN-MPC\\mppi\\PandaReach_MPPI_results_seed15_June27.npz")['arr_0']

# %%
episodic_return_seeds = np.array([PR_mppi_0, PR_mppi_8, PR_mppi_15])
mean_episodic_return = np.mean(episodic_return_seeds, axis=0)
std_episodic_return = np.std(episodic_return_seeds, axis=0)
save_data(prob, method_name, episodic_return_seeds, mean_episodic_return, std_episodic_return)

# %%
plt.plot(mean_episodic_return, label='MPPI')
plt.fill_between(range(len(mean_episodic_return)), mean_episodic_return - std_episodic_return, mean_episodic_return + std_episodic_return, alpha=0.2)
plt.xlabel('Episode')
plt.ylabel('Mean episodic return')
# Out:
# Text(0, 0.5, 'Mean episodic return')

# %% [markdown]
# ## Panda reach dense

# %%
prob = "PandaReachDense"

# %%
PRD_mppi_0 = np.load("C:\\Users\\nicle\\Desktop\\QRNN-MPC\\mppi\\PandaReachDense_MPPI_results_seed0_June27.npz")['arr_0'] #['mean_reward']
PRD_mppi_8 = np.load("C:\\Users\\nicle\\Desktop\\QRNN-MPC\\mppi\\PandaReachDense_MPPI_results_seed8_June27.npz")['arr_0']
PRD_mppi_15 = np.load("C:\\Users\\nicle\\Desktop\\QRNN-MPC\\mppi\\PandaReachDense_MPPI_results_seed15_June27.npz")['arr_0']

# %%
episodic_return_seeds = np.array([PRD_mppi_0, PRD_mppi_8, PRD_mppi_15])
mean_episodic_return = np.mean(episodic_return_seeds, axis=0)
std_episodic_return = np.std(episodic_return_seeds, axis=0)
save_data(prob, method_name, episodic_return_seeds, mean_episodic_return, std_episodic_return)

# %%
plt.plot(mean_episodic_return, label='MPPI')
plt.fill_between(range(len(mean_episodic_return)), mean_episodic_return - std_episodic_return, mean_episodic_return + std_episodic_return, alpha=0.2)
plt.xlabel('Episode')
plt.ylabel('Mean episodic return')
# Out:
# Text(0, 0.5, 'Mean episodic return')

# %% [markdown]
# ## Inverted pendulum

# %%
prob = "InvertedPendulum"

# %%
IP_mppi_0 = np.load("C:\\Users\\nicle\\Desktop\\QRNN-MPC\\mppi\\InvertedPendulum_MPPI_results_seed0_June25.npz")['arr_0'][:300] #['mean_reward']
IP_mppi_8 = np.load("C:\\Users\\nicle\\Desktop\\QRNN-MPC\\mppi\\InvertedPendulum_MPPI_results_seed8_June25.npz")['arr_0']
IP_mppi_15 = np.load("C:\\Users\\nicle\\Desktop\\QRNN-MPC\\mppi\\InvertedPendulum_MPPI_results_seed15_June25.npz")['arr_0']

# IP_mppi = np.load("C:\\Users\\nicle\\Desktop\\QRNN-MPC\\mppi\\InvertedPendulum_MPPI_results.npz")

# %%
# IP_mppi['episode_rewards'].shape

IP_mppi_0.shape, IP_mppi_8.shape, IP_mppi_15.shape
# Out:
# ((300,), (300,), (300,))

# %%
# plt.plot(IP_mppi['mean_rewards'], label='MPPI')
plt.plot(IP_mppi_0, label='MPPI seed 0')
plt.plot(IP_mppi_8, label='MPPI seed 8')
plt.plot(IP_mppi_15, label='MPPI seed 15')

# %%
episodic_return_seeds = np.array([IP_mppi_0, IP_mppi_8, IP_mppi_15])
mean_episodic_return = np.mean(episodic_return_seeds, axis=0)
std_episodic_return = np.std(episodic_return_seeds, axis=0)
save_data(prob, method_name, episodic_return_seeds, mean_episodic_return, std_episodic_return)

# %%
plt.plot(mean_episodic_return, label='MPPI')
plt.fill_between(range(len(mean_episodic_return)), mean_episodic_return - std_episodic_return, mean_episodic_return + std_episodic_return, alpha=0.2)
plt.xlabel('Episode')
plt.ylabel('Mean episodic return')
# Out:
# Text(0, 0.5, 'Mean episodic return')

# %% [markdown]
# ## Cart pole continuous

# %%
prob = "CartPoleContinuous"

# %%
CPC_mppi_0 = np.load("C:\\Users\\nicle\\Desktop\\QRNN-MPC\\mppi\\CPC_MPPI_results_seed0_June25.npz")['arr_0'][:300] #['mean_reward']
CPC_mppi_8 = np.load("C:\\Users\\nicle\\Desktop\\QRNN-MPC\\mppi\\CPC_MPPI_results_seed8_June25.npz")['arr_0']
CPC_mppi_15 = np.load("C:\\Users\\nicle\\Desktop\\QRNN-MPC\\mppi\\CPC_MPPI_results_seed15_June25.npz")['arr_0']

# IP_mppi = np.load("C:\\Users\\nicle\\Desktop\\QRNN-MPC\\mppi\\InvertedPendulum_MPPI_results.npz")

# %%
# IP_mppi['episode_rewards'].shape

CPC_mppi_0.shape, CPC_mppi_8.shape, CPC_mppi_15.shape
# Out:
# ((300,), (300,), (300,))

# %%
# plt.plot(IP_mppi['mean_rewards'], label='MPPI')
plt.plot(CPC_mppi_0, label='MPPI seed 0')
plt.plot(CPC_mppi_8, label='MPPI seed 8')
plt.plot(CPC_mppi_15, label='MPPI seed 15')

# %%
episodic_return_seeds = np.array([CPC_mppi_0, CPC_mppi_8, CPC_mppi_15])
mean_episodic_return = np.mean(episodic_return_seeds, axis=0)
std_episodic_return = np.std(episodic_return_seeds, axis=0)
save_data(prob, method_name, episodic_return_seeds, mean_episodic_return, std_episodic_return)

# %%
plt.plot(mean_episodic_return, label='MPPI')
plt.fill_between(range(len(mean_episodic_return)), mean_episodic_return - std_episodic_return, mean_episodic_return + std_episodic_return, alpha=0.2)
plt.xlabel('Episode')
plt.ylabel('Mean episodic return')
# Out:
# Text(0, 0.5, 'Mean episodic return')
