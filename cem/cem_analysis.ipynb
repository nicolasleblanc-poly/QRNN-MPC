# %%
import numpy as np
import matplotlib.pyplot as plt
import os

# %% [markdown]
# - Used for envs like Panda reach (sparse and dense) where the goal state depends on the seed and the results had to be saved for each seed

# %%
def save_data(prob, method_name, episodic_rep_returns, mean_episodic_returns, std_episodic_returns):

    # Get the folder where this script is located
    origin_folder = "C:\\Users\\nicle\\Desktop\\QRNN-MPC\\cem"
    # os.path.dirname(os.path.abspath(__file__))
    # Construct full path to save
    save_path = os.path.join(origin_folder, f"{prob}_{method_name}_results_June25.npz")

    np.savez(
    save_path,
    # f"{prob}_{method_name}_results.npz",
    episode_rewards=episodic_rep_returns,
    mean_rewards=mean_episodic_returns,
    std_rewards=std_episodic_returns
    )

# %%
method_name = "CEM"

# %% [markdown]
# ## Pendulum

# %%
PE_cem = np.load("C:\\Users\\nicle\\Desktop\\QRNN-MPC\\cem\\Pendulum_CEM_results_June25.npz")#['mean_reward']

# %%
PE_cem['episode_rewards'].shape
# Out:
# (3, 300)

# %%
plt.plot(PE_cem['mean_rewards'], label='CEM')

# %% [markdown]
# ## MuJoCo reacher

# %%
RE_cem = np.load("C:\\Users\\nicle\\Desktop\\QRNN-MPC\\cem\\MuJoCoReacher_CEM_results_June25.npz")#['mean_reward']\

# %%
RE_cem['episode_rewards'].shape
# Out:
# (3, 400)

# %%
plt.plot(RE_cem['mean_rewards'], label='CEM')
plt.xlabel('Episode')
plt.ylabel('Mean episodic return')
# Out:
# Text(0, 0.5, 'Mean episodic return')

# %% [markdown]
# ## Mountain car continuous

# %%
prob = "MountainCarContinuous"

# %%
# MCC_mppi = np.load("C:\\Users\\nicle\\Desktop\\QRNN-MPC\\mppi\\MountainCarContinuous_MPPI_results.npz")#['mean_reward']
MCC_cem_seed0 = np.load("C:\\Users\\nicle\\Desktop\\QRNN-MPC\\cem\\MountainCarContinuous_CEM_results_seed0_June25.npz")['arr_0']#['mean_reward']
MCC_cem_seed8 = np.load("C:\\Users\\nicle\\Desktop\\QRNN-MPC\\cem\\MountainCarContinuous_CEM_results_seed8_June25.npz")['arr_0']#['mean_reward']
MCC_cem_seed15 = np.load("C:\\Users\\nicle\\Desktop\\QRNN-MPC\\cem\\MountainCarContinuous_CEM_results_seed15_June25.npz")['arr_0']#['mean_reward']

# %%
# MCC_mppi['episode_rewards'].shape
MCC_cem_seed0.shape, MCC_cem_seed8.shape, MCC_cem_seed15.shape
# Out:
# ((300,), (300,), (300,))

# %%
# plt.plot(MCC_mppi['mean_rewards'], label='MPPI')
plt.plot(MCC_cem_seed0, label='CEM seed 0')
plt.plot(MCC_cem_seed8, label='CEM seed 8')
plt.plot(MCC_cem_seed15, label='CEM seed 15')
plt.xlabel('Episode')
plt.ylabel('Mean episodic return')
# Out:
# Text(0, 0.5, 'Mean episodic return')

# %%
episodic_return_seeds = np.array([MCC_cem_seed0, MCC_cem_seed8, MCC_cem_seed15])
mean_episodic_return = np.mean(episodic_return_seeds, axis=0)
std_episodic_return = np.std(episodic_return_seeds, axis=0)
save_data(prob, method_name, episodic_return_seeds, mean_episodic_return, std_episodic_return)

# %%
plt.plot(mean_episodic_return, label='CEM')
plt.fill_between(range(len(mean_episodic_return)), mean_episodic_return - std_episodic_return, mean_episodic_return + std_episodic_return, alpha=0.2)
plt.xlabel('Episode')
plt.ylabel('Mean episodic return')
# Out:
# Text(0, 0.5, 'Mean episodic return')

# %% [markdown]
# ## Lunar lander continuous

# %%
prob = "LunarLanderContinuous"

# %%
# # MCC_mppi = np.load("C:\\Users\\nicle\\Desktop\\QRNN-MPC\\mppi\\MountainCarContinuous_MPPI_results.npz")#['mean_reward']
LLC_cem_seed0 = np.load("C:\\Users\\nicle\\Desktop\\QRNN-MPC\\cem\\LunarLanderContinuous_cem_results_seed0_June25.npz")['arr_0']#['mean_reward']
LLC_cem_seed8 = np.load("C:\\Users\\nicle\\Desktop\\QRNN-MPC\\cem\\LunarLanderContinuous_cem_results_seed8_June25.npz")['arr_0']#['mean_reward']
LLC_cem_seed15 = np.load("C:\\Users\\nicle\\Desktop\\QRNN-MPC\\cem\\LunarLanderContinuous_cem_results_seed15_June25.npz")['arr_0']#['mean_reward']

# %%
# LLC_mppi_seed0['episode_rewards'].shape
LLC_cem_seed0.shape, LLC_cem_seed8.shape, LLC_cem_seed15.shape
# Out:
# ((300,), (300,), (300,))

# %%
# plt.plot(LLC_mppi['mean_rewards'], label='MPPI')
plt.plot(LLC_cem_seed0, label='CEM seed 0')
plt.plot(LLC_cem_seed8, label='CEM seed 8')
plt.plot(LLC_cem_seed15, label='CEM seed 15')
plt.xlabel('Episode')
plt.ylabel('Mean episodic return')
# Out:
# Text(0, 0.5, 'Mean episodic return')

# %%
episodic_return_seeds = np.array([LLC_cem_seed0, LLC_cem_seed8, LLC_cem_seed15])
mean_episodic_return = np.mean(episodic_return_seeds, axis=0)
std_episodic_return = np.std(episodic_return_seeds, axis=0)
save_data(prob, method_name, episodic_return_seeds, mean_episodic_return, std_episodic_return)

# %%
plt.plot(mean_episodic_return, label='CEM')
plt.fill_between(range(len(mean_episodic_return)), mean_episodic_return - std_episodic_return, mean_episodic_return + std_episodic_return, alpha=0.2)
plt.xlabel('Episode')
plt.ylabel('Mean episodic return')
# Out:
# Text(0, 0.5, 'Mean episodic return')

# %% [markdown]
# ## Panda reach

# %%
prob = "PandaReach"

# %%
PR_cem_0 = np.load("C:\\Users\\nicle\\Desktop\\QRNN-MPC\\cem\\PandaReach_CEM_results_seed0_June25.npz")['arr_0'] #['mean_reward']
PR_cem_8 = np.load("C:\\Users\\nicle\\Desktop\\QRNN-MPC\\cem\\PandaReach_CEM_results_seed8_June25.npz")['arr_0']
PR_cem_15 = np.load("C:\\Users\\nicle\\Desktop\\QRNN-MPC\\cem\\PandaReach_CEM_results_seed15_June25.npz")['arr_0']

# %%
plt.plot(PR_cem_0, label='CEM seed 0')
plt.plot(PR_cem_8, label='CEM seed 8')
plt.plot(PR_cem_15, label='CEM seed 15')

# %%
episodic_return_seeds = np.array([PR_cem_0, PR_cem_8, PR_cem_15])
mean_episodic_return = np.mean(episodic_return_seeds, axis=0)
std_episodic_return = np.std(episodic_return_seeds, axis=0)
save_data(prob, method_name, episodic_return_seeds, mean_episodic_return, std_episodic_return)

# %%
plt.plot(mean_episodic_return, label='MPPI')
plt.fill_between(range(len(mean_episodic_return)), mean_episodic_return - std_episodic_return, mean_episodic_return + std_episodic_return, alpha=0.2)
plt.xlabel('Episode')
plt.ylabel('Mean episodic return')
# Out:
# Text(0, 0.5, 'Mean episodic return')

# %% [markdown]
# ## Panda reach dense

# %%
prob = "PandaReachDense"

# %%
PRD_cem_0 = np.load("C:\\Users\\nicle\\Desktop\\QRNN-MPC\\cem\\PandaReachDense_CEM_results_seed0_June25.npz")['arr_0'] #['mean_reward']
PRD_cem_8 = np.load("C:\\Users\\nicle\\Desktop\\QRNN-MPC\\cem\\PandaReachDense_CEM_results_seed8_June25.npz")['arr_0']
PRD_cem_15 = np.load("C:\\Users\\nicle\\Desktop\\QRNN-MPC\\cem\\PandaReachDense_CEM_results_seed15_June25.npz")['arr_0']

# %%
episodic_return_seeds = np.array([PRD_cem_0, PRD_cem_8, PRD_cem_15])
mean_episodic_return = np.mean(episodic_return_seeds, axis=0)
std_episodic_return = np.std(episodic_return_seeds, axis=0)
save_data(prob, method_name, episodic_return_seeds, mean_episodic_return, std_episodic_return)

# %%
plt.plot(mean_episodic_return, label='CEM')
plt.fill_between(range(len(mean_episodic_return)), mean_episodic_return - std_episodic_return, mean_episodic_return + std_episodic_return, alpha=0.2)
plt.xlabel('Episode')
plt.ylabel('Mean episodic return')
# Out:
# Text(0, 0.5, 'Mean episodic return')

# %% [markdown]
# ## Inverted pendulum

# %%
prob = "InvertedPendulum"

# %%
IP_cem_0 = np.load("C:\\Users\\nicle\\Desktop\\QRNN-MPC\\cem\\InvertedPendulum_CEM_results_seed0_June25.npz")['arr_0'][:300] #['mean_reward']
IP_cem_8 = np.load("C:\\Users\\nicle\\Desktop\\QRNN-MPC\\cem\\InvertedPendulum_CEM_results_seed8_June25.npz")['arr_0']
IP_cem_15 = np.load("C:\\Users\\nicle\\Desktop\\QRNN-MPC\\cem\\InvertedPendulum_CEM_results_seed15_June25.npz")['arr_0']

# # IP_mppi = np.load("C:\\Users\\nicle\\Desktop\\QRNN-MPC\\mppi\\InvertedPendulum_MPPI_results.npz")

# %%
# # IP_mppi['episode_rewards'].shape

IP_cem_0.shape, IP_cem_8.shape, IP_cem_15.shape
# Out:
# ((300,), (300,), (300,))

# %%
# plt.plot(IP_mppi['mean_rewards'], label='MPPI')
plt.plot(IP_cem_0, label='CEM seed 0')
plt.plot(IP_cem_8, label='CEM seed 8')
plt.plot(IP_cem_15, label='CEM seed 15')

# %%
episodic_return_seeds = np.array([IP_cem_0, IP_cem_8, IP_cem_15])
mean_episodic_return = np.mean(episodic_return_seeds, axis=0)
std_episodic_return = np.std(episodic_return_seeds, axis=0)
save_data(prob, method_name, episodic_return_seeds, mean_episodic_return, std_episodic_return)

# %%
plt.plot(mean_episodic_return, label='cem')
plt.fill_between(range(len(mean_episodic_return)), mean_episodic_return - std_episodic_return, mean_episodic_return + std_episodic_return, alpha=0.2)
plt.xlabel('Episode')
plt.ylabel('Mean episodic return')
# Out:
# Text(0, 0.5, 'Mean episodic return')

# %% [markdown]
# ## Cart pole continuous

# %%
prob = "CPC"

# %%
CPC_cem_0 = np.load("C:\\Users\\nicle\\Desktop\\QRNN-MPC\\cem\\CPC_CEM_results_seed0_June25.npz")['arr_0'][:300] #['mean_reward']
CPC_cem_8 = np.load("C:\\Users\\nicle\\Desktop\\QRNN-MPC\\cem\\CPC_CEM_results_seed8_June25.npz")['arr_0']
CPC_cem_15 = np.load("C:\\Users\\nicle\\Desktop\\QRNN-MPC\\cem\\CPC_CEM_results_seed15_June25.npz")['arr_0']

# IP_mppi = np.load("C:\\Users\\nicle\\Desktop\\QRNN-MPC\\mppi\\InvertedPendulum_MPPI_results.npz")

# %%
CPC_cem_0.shape, CPC_cem_8.shape, CPC_cem_15.shape
# Out:
# ((300,), (300,), (300,))

# %%
# plt.plot(IP_mppi['mean_rewards'], label='MPPI')
plt.plot(CPC_cem_0, label='CEM seed 0')
plt.plot(CPC_cem_8, label='CEM seed 8')
plt.plot(CPC_cem_15, label='CEM seed 15')

# %%
episodic_return_seeds = np.array([CPC_cem_0, CPC_cem_8, CPC_cem_15])
mean_episodic_return = np.mean(episodic_return_seeds, axis=0)
std_episodic_return = np.std(episodic_return_seeds, axis=0)
save_data(prob, method_name, episodic_return_seeds, mean_episodic_return, std_episodic_return)

# %%
plt.plot(mean_episodic_return, label='CEM')
plt.fill_between(range(len(mean_episodic_return)), mean_episodic_return - std_episodic_return, mean_episodic_return + std_episodic_return, alpha=0.2)
plt.xlabel('Episode')
plt.ylabel('Mean episodic return')
# Out:
# Text(0, 0.5, 'Mean episodic return')
