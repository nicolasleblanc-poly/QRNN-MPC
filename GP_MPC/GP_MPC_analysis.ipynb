# %%
import numpy as np
import matplotlib.pyplot as plt
import gymnasium as gym
import panda_gym

# %% [markdown]
# ## Tests

# %% [markdown]
# ### MuJoCo reacher

# %%
env = gym.make("Reacher-v5")
print(env.observation_space.low[:8])
obs, info = env.reset(seed=0)
goal_state_seed0 = obs[-2:]

obs, info = env.reset(seed=8)
goal_state_seed8 = obs[-2:]

obs, info = env.reset(seed=15)
goal_state_seed15 = obs[-2:]

print("goal_state_seed0 ", goal_state_seed0)
print("goal_state_seed8 ", goal_state_seed8)
print("goal_state_seed15 ", goal_state_seed15)
# Out:
# [-inf -inf -inf -inf -inf -inf -inf -inf]
# goal_state_seed0  [ 0.16728904 -0.09111115]
# goal_state_seed8  [0.06176434 0.04701514]
# goal_state_seed15  [0.1807183  0.15652479]

# %% [markdown]
# ### Panda reach

# %%
env = gym.make("PandaReach-v3")
obs, info = env.reset(seed=0)
goal_state_seed0 = obs['desired_goal']

obs, info = env.reset(seed=8)
goal_state_seed8 = obs['desired_goal']

obs, info = env.reset(seed=15)
goal_state_seed15 = obs['desired_goal']

print("goal_state_seed0 ", goal_state_seed0)
print("goal_state_seed8 ", goal_state_seed8)
print("goal_state_seed15 ", goal_state_seed15)
# Out:
# goal_state_seed0  [ 0.04108851 -0.06906398  0.01229206]
# goal_state_seed8  [-0.05190832  0.14618306  0.09561325]
# goal_state_seed15  [0.05782301 0.09474514 0.10332203]

# %%
obs
# Out:
# {'observation': array([ 3.8439669e-02, -2.1944723e-12,  1.9740014e-01,  0.0000000e+00,
#         -0.0000000e+00,  0.0000000e+00], dtype=float32),
#  'achieved_goal': array([ 3.8439669e-02, -2.1944723e-12,  1.9740014e-01], dtype=float32),
#  'desired_goal': array([0.05782301, 0.09474514, 0.10332203], dtype=float32)}

# %% [markdown]
# ## Pendulum

# %%
# PE_data = np.load('C:\\Users\\nicle\\anaconda3\\envs\\handful2\\Data-Efficient-Reinforcement-Learning-with-Probabilistic-Model-Predictive-Control-master\\InvertedPendulum_GP-MPC_results.npz')
# PE_data = np.load("C:\\Users\\nicle\\Desktop\\QRNN-MPC\\GP_MPC\\Pendulum_GP-MPC_results.npz")
PE_data = np.load("C:\\Users\\nicle\\Desktop\\QRNN-MPC\\GP_MPC\\examples\\pendulum\\Pendulum_GP-MPC_results.npz")

# %%
plt.plot(PE_data['mean_rewards'])
plt.fill_between(
    np.arange(len(PE_data['mean_rewards'])),
    PE_data['mean_rewards'] - PE_data['std_rewards'],
    PE_data['mean_rewards'] + PE_data['std_rewards'],
    alpha=0.2,
)

# %% [markdown]
# ## Inverted pendulum

# %%
# IP_data = np.load('C:\\Users\\nicle\\anaconda3\\envs\\handful2\\Data-Efficient-Reinforcement-Learning-with-Probabilistic-Model-Predictive-Control-master\\InvertedPendulum_GP-MPC_results.npz')
IP_data = np.load("C:\\Users\\nicle\\Desktop\\QRNN-MPC\\GP_MPC\\InvertedPendulum_GP-MPC_results.npz")

# %%
plt.plot(IP_data['mean_rewards'])
plt.fill_between(
    np.arange(len(IP_data['mean_rewards'])),
    IP_data['mean_rewards'] - IP_data['std_rewards'],
    IP_data['mean_rewards'] + IP_data['std_rewards'],
    alpha=0.2,
)

# %% [markdown]
# ## Continuous lunar lander

# %%
# # LLC_data = np.load('C:\\Users\\nicle\\anaconda3\\envs\\handful2\\Data-Efficient-Reinforcement-Learning-with-Probabilistic-Model-Predictive-Control-master\\LunarLanderContinuous_GP-MPC_results.npz')
# LLC_data = np.load("C:\\Users\\nicle\\Desktop\\QRNN-MPC\\GP_MPC\\LunarLanderContinuous_GP-MPC_results.npz")
LLC_data = np.load("C:\\Users\\nicle\\Desktop\\QRNN-MPC\\GP_MPC\\examples\\lunar_lander\\LunarLander_GP-MPC_results.npz")

# %%
plt.plot(LLC_data['mean_rewards'])
plt.fill_between(
    np.arange(len(LLC_data['mean_rewards'])),
    LLC_data['mean_rewards'] - LLC_data['std_rewards'],
    LLC_data['mean_rewards'] + LLC_data['std_rewards'],
    alpha=0.2,
)

# %% [markdown]
# ## Continuous mountain car

# %%
# MCC_data = np.load('C:\\Users\\nicle\\anaconda3\\envs\\handful2\\Data-Efficient-Reinforcement-Learning-with-Probabilistic-Model-Predictive-Control-master\\MountainCarContinuous_GP-MPC_results.npz')
# MCC_data = np.load("C:\\Users\\nicle\\Desktop\\QRNN-MPC\\GP_MPC\\MountainCarContinuous_GP-MPC_results.npz")
MCC_data = np.load("C:\\Users\\nicle\\Desktop\\QRNN-MPC\\GP_MPC\\examples\\mountain_car\\MountainCar_GP-MPC_results.npz")

# %%
plt.plot(MCC_data['mean_rewards'])
plt.fill_between(
    np.arange(len(MCC_data['mean_rewards'])),
    MCC_data['mean_rewards'] - MCC_data['std_rewards'],
    MCC_data['mean_rewards'] + MCC_data['std_rewards'],
    alpha=0.2,
)

# %% [markdown]
# ## MuJoCo reacher

# %%
# RE_data = np.load('C:\\Users\\nicle\\anaconda3\\envs\\handful2\\Data-Efficient-Reinforcement-Learning-with-Probabilistic-Model-Predictive-Control-master\\MuJoCoReacher_GP-MPC_results.npz')
RE_data = np.load("C:\\Users\\nicle\\Desktop\\QRNN-MPC\\GP_MPC\\MuJoCoReacher_GP-MPC_results.npz")

# %%
plt.plot(RE_data['mean_rewards'])
plt.fill_between(
    np.arange(len(RE_data['mean_rewards'])),
    RE_data['mean_rewards'] - RE_data['std_rewards'],
    RE_data['mean_rewards'] + RE_data['std_rewards'],
    alpha=0.2,
)

# %% [markdown]
# ## Panda reach

# %%
# PR_data = np.load('C:\\Users\\nicle\\anaconda3\\envs\\handful2\\Data-Efficient-Reinforcement-Learning-with-Probabilistic-Model-Predictive-Control-master\\PandaReach_GP-MPC_results.npz')
PR_data = np.load("C:\\Users\\nicle\\Desktop\\QRNN-MPC\\GP_MPC\\PandaReach_GP-MPC_results.npz")

# %%
plt.plot(PR_data['mean_rewards'])
plt.fill_between(
    np.arange(len(PR_data['mean_rewards'])),
    PR_data['mean_rewards'] - PR_data['std_rewards'],
    PR_data['mean_rewards'] + PR_data['std_rewards'],
    alpha=0.2,
)

# %% [markdown]
# ## Panda reach dense

# %%
# PR_data = np.load('C:\\Users\\nicle\\anaconda3\\envs\\handful2\\Data-Efficient-Reinforcement-Learning-with-Probabilistic-Model-Predictive-Control-master\\PandaReach_GP-MPC_results.npz')
PRD_data = np.load("C:\\Users\\nicle\\Desktop\\QRNN-MPC\\GP_MPC\\PandaReachDense_GP-MPC_results.npz")

# %%
plt.plot(PRD_data['mean_rewards'])
plt.fill_between(
    np.arange(len(PRD_data['mean_rewards'])),
    PRD_data['mean_rewards'] - PRD_data['std_rewards'],
    PRD_data['mean_rewards'] + PRD_data['std_rewards'],
    alpha=0.2,
)
